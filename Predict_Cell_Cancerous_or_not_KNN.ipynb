# %% [markdown]
# **PREDICTING WHETHER THE CELL IS BENIGN OR MALIGNANT**

# %%
# PREDICTING BREAST CANCER 

# We are using Breast Cncer Wisconsin(Diagnostic) Dataset from UCI Repository

# We will be using KNN algorithm to predict whether the cell is Benign or Malignant

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wisc_bc_data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
# diagnosis is the target variable 
# B - Benign - not cancerous
# M - Malignant - cancerous

# %%
df.shape
# Out:
# (569, 32)

# %%
df.dtypes
# Out:
# id                     int64
# diagnosis             object
# radius_mean          float64
# texture_mean         float64
# perimeter_mean       float64
# area_mean            float64
# smoothness_mean      float64
# compactness_mean     float64
# concavity_mean       float64
# points_mean          float64
# symmetry_mean        float64
# dimension_mean       float64
# radius_se            float64
# texture_se           float64
# perimeter_se         float64
# area_se              float64
# smoothness_se        float64
# compactness_se       float64
# concavity_se         float64
# points_se            float64
# symmetry_se          float64
# dimension_se         float64
# radius_worst         float64
# texture_worst        float64
# perimeter_worst      float64
# area_worst           float64
# smoothness_worst     float64
# compactness_worst    float64
# concavity_worst      float64
# points_worst         float64
# symmetry_worst       float64
# dimension_worst      float64
# ...

# %%
df["diagnosis"] = df["diagnosis"].astype("category")

# %%
df["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df = df.drop("id",axis=1)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B        12.32         12.39           78.85      464.1
# 1         B        10.60         18.95           69.28      346.4
# 2         B        11.04         16.83           70.92      373.2
# 3         B        11.28         13.39           73.00      384.8
# 4         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          0.10280           0.06981         0.03987      0.03700
# 1          0.09688           0.11470         0.06387      0.02642
# 2          0.10770           0.07804         0.03046      0.02480
# 3          0.11640           0.11360         0.04635      0.04796
# 4          0.07963           0.06934         0.03393      0.02657
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.1959  ...         13.50          15.64            86.97
# ...

# %%
x = df.drop(["diagnosis"],axis=1)
y = df["diagnosis"]

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          12.32         12.39           78.85      464.1          0.10280
# 1          10.60         18.95           69.28      346.4          0.09688
# 2          11.04         16.83           70.92      373.2          0.10770
# 3          11.28         13.39           73.00      384.8          0.11640
# 4          15.19         13.21           97.65      711.8          0.07963
# ..           ...           ...             ...        ...              ...
# 564        13.17         18.22           84.28      537.3          0.07466
# 565        10.26         14.71           66.20      321.6          0.09882
# 566        15.28         22.41           98.92      710.6          0.09057
# 567        14.53         13.98           93.86      644.2          0.10990
# 568        21.37         15.10          141.30     1386.0          0.10010
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# ...

# %%
y
# Out:
# 0      B
# 1      B
# 2      B
# 3      B
# 4      B
#       ..
# 564    B
# 565    B
# 566    M
# 567    B
# 568    M
# Name: diagnosis, Length: 569, dtype: category
# Categories (2, object): ['B', 'M']

# %%
# STANDARDIZE OUR DATA 
from scipy.stats import zscore
xScaled=x.apply(zscore)

# %%
xScaled.describe()
# Out:
#         radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -1.576556e-16 -7.711075e-16   -1.186319e-16 -2.029230e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean   points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02  5.690000e+02
# mean      1.717041e-16      1.935573e-16    4.058460e-17 -5.619407e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00  1.000880e+00
# min      -3.112085e+00     -1.610136e+00   -1.114873e+00 -1.261820e+00
# ...

# %%
xScaled_df = pd.DataFrame(xScaled)

# %%
xScaled.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0    -0.513297     -1.605595       -0.540376  -0.542624         0.458285
# 1    -1.001801     -0.079038       -0.934566  -0.877375         0.036986
# 2    -0.876835     -0.572377       -0.867014  -0.801153         0.806996
# 3    -0.808671     -1.372888       -0.781338  -0.768161         1.426135
# 4     0.301824     -1.414775        0.234000   0.161860        -1.190618
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0         -0.654413       -0.614306    -0.307442       0.538081
# 1          0.196319       -0.312987    -0.580343       0.402996
# 2         -0.498443       -0.732448    -0.622129      -0.356400
# 3          0.175472       -0.532950    -0.024740      -0.148296
# 4         -0.663320       -0.688883    -0.576473      -0.330843
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# STD -same !!! This is our goal !!!

# %%
# BUILDING KNN MODEL

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(xScaled_df,y,test_size = 0.3,random_state =1)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 249    -0.604181      2.080480       -0.626051  -0.604056        -0.853294
# 58      2.874993      0.211845        3.057588   3.145893         3.440117
# 476    -0.589980      0.798266       -0.544495  -0.588983        -1.922199
# 529    -1.266502     -0.276839       -1.273149  -1.048305        -0.942962
# 422    -0.845593     -1.445027       -0.869073  -0.776409         0.083955
# ..           ...           ...             ...        ...              ...
# 129     0.040531      0.758706        0.074182  -0.071356         0.529451
# 144     0.128576      0.521345        0.224115  -0.028694         0.643316
# 72     -1.444295     -0.090674       -1.313928  -1.167189         0.236249
# 235    -0.695066     -0.725963       -0.678775  -0.666627         1.169940
# 37     -0.632582     -1.079677       -0.570856  -0.631644         1.340737
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# ...

# %%
x_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 421     0.276263      0.635371        0.217936   0.164705        -0.412780
# 47      3.295334     -0.425771        3.387110   3.854074         1.319387
# 292    -0.101476      0.698202       -0.055155  -0.187680         1.682331
# 186     0.830091     -0.048787        0.882746   0.682900         1.262455
# 414    -0.678025     -1.226283       -0.730262  -0.647287        -1.297366
# ..           ...           ...             ...        ...              ...
# 6      -0.743348      1.079841       -0.718729  -0.714976        -0.266890
# 487     2.312645      0.088510        2.505640   2.429179         2.579016
# 11     -0.533178     -0.314072       -0.564266  -0.553431        -0.698865
# 268    -0.533178      0.733108       -0.567973  -0.535798        -1.027649
# 419    -0.660984     -0.630553       -0.534609  -0.633919         0.906628
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# ...

# %%
y_train
# Out:
# 249    B
# 58     M
# 476    B
# 529    B
# 422    B
#       ..
# 129    M
# 144    M
# 72     B
# 235    B
# 37     B
# Name: diagnosis, Length: 398, dtype: category
# Categories (2, object): ['B', 'M']

# %%
y_test
# Out:
# 421    M
# 47     M
# 292    M
# 186    M
# 414    B
#       ..
# 6      B
# 487    M
# 11     B
# 268    B
# 419    M
# Name: diagnosis, Length: 171, dtype: category
# Categories (2, object): ['B', 'M']

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier(n_neighbors=5,weights = 'distance')

# %%
# uniform - uniform weights .All points in each neighboorhood are weighted equally 
# distance - weigth points by the inverse of their distance.in this case closer neighbors of a query point will be important

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
KNN_predict = KNN.predict(x_test)

# %%
KNN_predict
# Out:
# array(['M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M'], dtype=object)

# %%
KNN.score(x_test,y_test)
# Out:
# 0.9649122807017544

# %%
from sklearn import metrics 

print('Confusion matrix')

cm = metrics.confusion_matrix(y_test,KNN_predict,labels=['M','B'])
df_cm = pd.DataFrame(cm,index=[i for i in ['M','B']],
                    columns = [ i for i in ['Predict M','Predict B']])

sns.heatmap(df_cm,annot=True)

plt.show()
# Out:
# Confusion matrix

# %%
# CHOOSING K

# %%
import warnings 
warnings.filterwarnings('ignore')
from  sklearn.model_selection import cross_val_score

score_1 = []

for i in range(1,50):
    KNN_2 = KNeighborsClassifier(n_neighbors =i)
    score_2 = cross_val_score(KNN_2,xScaled_df,y,cv=10)
    score_1.append(score_2.mean())

# %%
score_2
# Out:
# array([0.96491228, 0.94736842, 0.94736842, 0.92982456, 0.96491228,
#        0.98245614, 0.92982456, 0.94736842, 0.94736842, 0.96428571])

# %%
score_1
# Out:
# [0.9490914786967419,
#  0.9560776942355889,
#  0.9666040100250626,
#  0.9648809523809525,
#  0.9683897243107771,
#  0.9631265664160402,
#  0.9683897243107771,
#  0.9666353383458647,
#  0.9701441102756894,
#  0.9648809523809524,
#  0.9683897243107771,
#  0.9683897243107771,
#  0.9666040100250626,
#  0.9613721804511279,
#  0.9648809523809524,
#  0.9595864661654134,
#  0.9613721804511279,
#  0.9613721804511279,
#  0.9596177944862155,
#  0.9596177944862155,
#  0.9578634085213034,
#  0.9561090225563911,
#  0.9596177944862155,
#  0.956077694235589,
#  0.956077694235589,
#  0.9543233082706767,
#  0.9578634085213034,
#  0.9543233082706767,
#  0.9560776942355889,
#  0.9560776942355889,
#  0.9560776942355889,
#  0.9543233082706767,
#  0.9560776942355889,
#  0.9543233082706767,
#  0.956077694235589,
#  0.9578320802005011,
#  0.956077694235589,
#  0.9543233082706767,
#  0.956077694235589,
#  0.956077694235589,
#  0.956077694235589,
#  0.956077694235589,
#  0.956077694235589,
# ...

# %%
len(score_1)
# Out:
# 49

# %%
plt.figure(figsize=(20,10))
plt.plot(range(1,50),score_1,color='blue',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)

plt.title("Accuracy Rate Vs K-Values")
plt.xlabel("K")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# Perfecct K is 9 !!! K to be an odd number !! Thats good !!

# %%
KNN= KNeighborsClassifier(n_neighbors=10,weights='distance')

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10, weights='distance')

# %%
KNN.score(x_test,y_test)
# Out:
# 0.9707602339181286

# %%
KNN= KNeighborsClassifier(n_neighbors=50,weights='distance')

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=50, weights='distance')

# %%
KNN.score(x_test,y_test)
# Out:
# 0.9532163742690059
